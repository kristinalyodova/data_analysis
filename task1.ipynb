# %% [markdown]
# # МОСКОВСКИЙ АВИАЦИОННЫЙ ИНСТИТУТ
# # (Национальный исследовательский университет)
#
# # **Домашняя работа №1**
# # **по дисциплине: "Анализ данных"**
#
# ## Выполнила:
# ## **студентка группы Т12О-101М-20**
# ## **Лёдова Кристина**
#
# ## Преподаватель:
# ## **Джумурат Александр**
#
# #### Москва, 2021 г.

# %% [markdown]
# ***Условие задачи:***
#
# Рассмотрим трафик на карточке с фильмом в ivi. На прямые переходы из поисковых сист приходится в два раза больше трафика, чем на просмотры из центрального промо-блока.
#
# При этом конверсия в просмотр при прямом заходе составляет 0.1, а конверсия в просмотр при переходе с ЦПБ 0.3. Найти вероятность того, что случайно зашедший пользователь совершит просмотр.

# %%
# Событие A - зашедший пользователь совершит просмотр
# Примем трафик за 1, тогда:
# Гипотеза B1 - прямые переходы в 2 раза больше --> 2/3 пользователей
# Гипотеза B2 - переходы из цетрального промо-блока --> 1/3 пользователей 
# Согласно формуле полной вероятности:
# P(A) = 2/3 * 0.1 + 1/3 * 0.3

def views():
    p = 2/3 * 0.1 + 1/3 * 0.3    
    return p
print('%.5f' % views ())
# Out:
# 0.16667
